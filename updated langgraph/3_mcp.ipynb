# %% [markdown]
# ### MCP
# ### Transport stdio & http implementation

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 MCP
#
# NameError: name 'MCP' is not defined
